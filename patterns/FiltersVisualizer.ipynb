# %%
import sv_utils
import torch 
import numpy as np
import pylab as plt
from matplotlib import pyplot
from matplotlib.pyplot import figure
from os.path import dirname, realpath
from singleNeuron import preSpikes, nextSpikes, STDPLIFDensePopulation

# %% [markdown]
# # Filter Visualizer

# %% [markdown]
# El proposito de esta notebook es el poder graficar el peso de los filtros de los distintos layers

# %% [markdown]
# ## Visualizacion de los filtros

# %% [markdown]
# ### Filtros 1er Layer (Sin delay)

# %%
# Load and set img size
filters = np.load('../cleanDSNN/results/old_results/p_18/limited_spikes/weights/0_0_30/weight_0.npy')
figure(figsize=(18,18))
print(filters.shape)

n_filters, ix = filters.shape[3], 1
for i in range(n_filters):
    # get the filter
    f = filters[:, :, :, i]
    f = np.squeeze(f)

    # specify subplot and turn of axis
    ax = pyplot.subplot(n_filters, 4, ix)
    ax.set_xticks([])
    ax.set_yticks([])
    # plot filter channel in grayscale
    pyplot.imshow(f, cmap='gray')
    ix += 1
# show the figure
pyplot.show()
# Out:
# (7, 7, 1, 8)

# %% [markdown]
# ### Filtros 2do Layer (Sin delay)

# %%
# Load and set img size
filters = np.load('../cleanDSNN/results/old_results/p_18/limited_spikes/15_0_0/weights/weight_2.npy')
figure(figsize=(18,18))
print(filters.shape)

channels, n_filters, ix = filters.shape[2], filters.shape[3], 1
for i in range(n_filters):
    # get the filter
    f = filters[:, :, :, i]
    f = np.squeeze(f)
    for j in range(channels):
        # specify subplot and turn of axis
        ax = pyplot.subplot(n_filters, channels, ix)
        ax.set_xticks([])
        ax.set_yticks([])
        # plot filter channel in grayscale
        pyplot.imshow(f[:, :, j], cmap='gray')
        ix += 1
# show the figure
pyplot.show()
# Out:
# (5, 5, 8, 20)

# %% [markdown]
# ### Filtros 3er Layer (Sin delay)

# %%
# Load and set img size
filters = np.load('../cleanDSNN/results/old_results/p_18/5_0_0/weights/weight_4.npy')
figure(figsize=(15,15))
print(filters.shape)

channels, n_filters, ix = filters.shape[2], filters.shape[3], 1
for i in range(n_filters):
    # get the filter
    f = filters[:, :, :, i]
    f = np.squeeze(f)
    for j in range(channels):
        # specify subplot and turn of axis
        ax = pyplot.subplot(n_filters, channels, ix)
        ax.set_xticks([])
        ax.set_yticks([])
        # plot filter channel in grayscale
        pyplot.imshow(f[:, :, j], cmap='gray')
        ix += 1
# show the figure
pyplot.show()
# Out:
# (3, 3, 20, 20)

# %% [markdown]
# ### Filtros 1er Layer (Con delay -> 15, 5, 0)

# %%
# Load and set img size
filters = np.load('../cleanDSNN/results/old_results/p_18_delays/p_18/weights/weight_0.npy')
figure(figsize=(18,18))
print(filters.shape)

n_filters, ix = filters.shape[3], 1
for i in range(n_filters):
    # get the filter
    f = filters[:, :, :, i]
    f = np.squeeze(f)

    # specify subplot and turn of axis
    ax = pyplot.subplot(n_filters, 4, ix)
    ax.set_xticks([])
    ax.set_yticks([])
    # plot filter channel in grayscale
    pyplot.imshow(f, cmap='gray')
    ix += 1
# show the figure
pyplot.show()
# Out:
# (7, 7, 1, 8)

# %% [markdown]
# ### Filtros 2do Layer (Con delay -> 15, 5, 0)

# %%
# Load and set img size
filters = np.load('../cleanDSNN/results/old_results/p_18_delays/p_18/weights/weight_2.npy')
figure(figsize=(18,18))
print(filters.shape)

channels, n_filters, ix = filters.shape[2], filters.shape[3], 1
for i in range(n_filters):
    # get the filter
    f = filters[:, :, :, i]
    f = np.squeeze(f)
    for j in range(channels):
        # specify subplot and turn of axis
        ax = pyplot.subplot(n_filters, channels, ix)
        ax.set_xticks([])
        ax.set_yticks([])
        # plot filter channel in grayscale
        pyplot.imshow(f[:, :, j], cmap='gray')
        ix += 1
# show the figure
pyplot.show()
# Out:
# (5, 5, 8, 20)

# %% [markdown]
# ## Filtros 1er Layer (Con delay -> 10, 5, 0)

# %%
# Load and set img size
filters = np.load('../cleanDSNN/results/old_results/p_18_delays-2/p_18/weights/weight_0.npy')
figure(figsize=(18,18))
print(filters.shape)

n_filters, ix = filters.shape[3], 1
for i in range(n_filters):
    # get the filter
    f = filters[:, :, :, i]
    f = np.squeeze(f)

    # specify subplot and turn of axis
    ax = pyplot.subplot(n_filters, 4, ix)
    ax.set_xticks([])
    ax.set_yticks([])
    # plot filter channel in grayscale
    pyplot.imshow(f, cmap='gray')
    ix += 1
# show the figure
pyplot.show()
# Out:
# (7, 7, 1, 8)

# %% [markdown]
# ## Filtros 2do Layer (Con delay -> 15, 5, 0)

# %%
# Load and set img size
filters = np.load('../cleanDSNN/results/old_results/p_18_delays-2/p_18/weights/weight_2.npy')
figure(figsize=(18,18))
print(filters.shape)

channels, n_filters, ix = filters.shape[2], filters.shape[3], 1
for i in range(n_filters):
    # get the filter
    f = filters[:, :, :, i]
    f = np.squeeze(f)
    for j in range(channels):
        # specify subplot and turn of axis
        ax = pyplot.subplot(n_filters, channels, ix)
        ax.set_xticks([])
        ax.set_yticks([])
        # plot filter channel in grayscale
        pyplot.imshow(f[:, :, j], cmap='gray')
        ix += 1
# show the figure
pyplot.show()
# Out:
# (5, 5, 8, 20)
